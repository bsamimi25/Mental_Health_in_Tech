# %%
# Load Libraries
import psycopg2
import pandas as pd
import numpy as np

# %%
from config import password

#  Connect to PostgreSQL

con = psycopg2.connect(
        host= '127.0.0.1',
        database= 'mental_health_db',
        user= 'postgres',
        password=password
)

# %%
#Retreive data from PostgreSQL Server
cur = con.cursor()

cur.execute("select * from table_1")

rows= cur.fetchall()

rows
# Out:
# [(datetime.datetime(2014, 8, 27, 11, 29),
#   37,
#   'Female',
#   'United States',
#   'IL',
#   'NA',
#   'No',
#   'Yes',
#   'Often',
#   '25-Jun',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'No',
#   'Yes',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 29),
#   44,
#   'M',
#   'United States',
#   'IN',
#   'NA',
#   'No',
#   'No',
#   'Rarely',
#   'More than 1000',
#   'No',
#   'No',
#   "Don't know",
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 29),
#   32,
#   'Male',
#   'Canada',
#   'NA',
#   'NA',
#   'No',
#   'No',
#   'Rarely',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat difficult',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 29),
#   31,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'NA',
#   'Yes',
#   'Yes',
#   'Often',
#   '26-100',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Somewhat difficult',
#   'Yes',
#   'Yes',
#   'Some of them',
#   'No',
#   'Maybe',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 11, 30),
#   31,
#   'Male',
#   'United States',
#   'TX',
#   'NA',
#   'No',
#   'No',
#   'Never',
#   '100-500',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 31),
#   33,
#   'Male',
#   'United States',
#   'TN',
#   'NA',
#   'Yes',
#   'No',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 31),
#   35,
#   'Female',
#   'United States',
#   'MI',
#   'NA',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Somewhat difficult',
#   'Maybe',
#   'Maybe',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 32),
#   39,
#   'M',
#   'Canada',
#   'NA',
#   'NA',
#   'No',
#   'No',
#   'Never',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 32),
#   42,
#   'Female',
#   'United States',
#   'IL',
#   'NA',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '100-500',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Very difficult',
#   'Maybe',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 32),
#   23,
#   'Male',
#   'Canada',
#   'NA',
#   'NA',
#   'No',
#   'No',
#   'Never',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 32),
#   31,
#   'Male',
#   'United States',
#   'OH',
#   'NA',
#   'No',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 32),
#   29,
#   'male',
#   'Bulgaria',
#   'NA',
#   'NA',
#   'No',
#   'No',
#   'Never',
#   '100-500',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 33),
#   42,
#   'female',
#   'United States',
#   'CA',
#   'NA',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat difficult',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 11, 33),
#   36,
#   'Male',
#   'United States',
#   'CT',
#   'NA',
#   'Yes',
#   'No',
#   'Never',
#   '500-1000',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 33),
#   27,
#   'Male',
#   'Canada',
#   'NA',
#   'NA',
#   'No',
#   'No',
#   'Never',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'Maybe',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 34),
#   29,
#   'female',
#   'United States',
#   'IL',
#   'NA',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Yes',
#   'Some of them',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 34),
#   23,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'NA',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Very easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'Maybe',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 34),
#   32,
#   'Male',
#   'United States',
#   'TN',
#   'NA',
#   'No',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 34),
#   46,
#   'male',
#   'United States',
#   'MD',
#   'Yes',
#   'Yes',
#   'No',
#   'Sometimes',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'Yes',
#   "Don't know",
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 11, 35),
#   36,
#   'Male',
#   'France',
#   'NA',
#   'Yes',
#   'Yes',
#   'No',
#   'NA',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 35),
#   29,
#   'Male',
#   'United States',
#   'NY',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '100-500',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Somewhat difficult',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 35),
#   31,
#   'male',
#   'United States',
#   'NC',
#   'Yes',
#   'No',
#   'No',
#   'Never',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat difficult',
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 35),
#   46,
#   'Male',
#   'United States',
#   'MA',
#   'No',
#   'No',
#   'Yes',
#   'Often',
#   '26-100',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 36),
#   41,
#   'Male',
#   'United States',
#   'IA',
#   'No',
#   'No',
#   'Yes',
#   'Never',
#   'More than 1000',
#   'No',
#   'No',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 36),
#   33,
#   'male',
#   'United States',
#   'CA',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   "Don't know",
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 37),
#   35,
#   'male',
#   'United States',
#   'TN',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   'More than 1000',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   "Don't know",
#   'No',
#   'Very easy',
#   'Yes',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 37),
#   33,
#   'male',
#   'United States',
#   'TN',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '5-Jan',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'Maybe',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 37),
#   35,
#   'Female',
#   'United States',
#   'CA',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 38),
#   34,
#   'male',
#   'United States',
#   'OH',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Somewhat difficult',
#   'No',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 38),
#   37,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Very difficult',
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 39),
#   32,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Yes',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 38),
#   31,
#   'Male',
#   'United States',
#   'PA',
#   'Yes',
#   'Yes',
#   'No',
#   'Rarely',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat difficult',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 11, 39),
#   30,
#   'male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '500-1000',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 39),
#   42,
#   'Male',
#   'United States',
#   'WA',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Very easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'Maybe',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 40),
#   40,
#   'female',
#   'United States',
#   'WI',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '5-Jan',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 41),
#   27,
#   'Male',
#   'United States',
#   'NY',
#   'No',
#   'No',
#   'Yes',
#   'Rarely',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 41),
#   29,
#   'Male',
#   'Canada',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Rarely',
#   '5-Jan',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Very easy',
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 41),
#   38,
#   'Male',
#   'Portugal',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '100-500',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 42),
#   50,
#   'M',
#   'United States',
#   'IN',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '100-500',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 42),
#   35,
#   'M',
#   'United States',
#   'TX',
#   'No',
#   'No',
#   'Yes',
#   'Rarely',
#   'More than 1000',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 42),
#   24,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'Maybe',
#   'Some of them',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 11, 42),
#   35,
#   'Male',
#   'United States',
#   'MI',
#   'No',
#   'No',
#   'No',
#   'NA',
#   'More than 1000',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Not sure',
#   "Don't know",
#   'Yes',
#   "Don't know",
#   'Somewhat difficult',
#   'Yes',
#   'Yes',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 43),
#   27,
#   'Male',
#   'Canada',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '5-Jan',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Very difficult',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 43),
#   18,
#   'Male',
#   'Netherlands',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Often',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat difficult',
#   'Yes',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 43),
#   30,
#   'Male',
#   'United States',
#   'IN',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 43),
#   38,
#   'Female',
#   'United States',
#   'TX',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 43),
#   28,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'Maybe',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 43),
#   34,
#   'Male',
#   'United States',
#   'TN',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 43),
#   26,
#   'm',
#   'Canada',
#   'NA',
#   'Yes',
#   'No',
#   'No',
#   'Sometimes',
#   '5-Jan',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 44),
#   30,
#   'male',
#   'United States',
#   'IL',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 44),
#   22,
#   'M',
#   'United States',
#   'TX',
#   'No',
#   'Yes',
#   'Yes',
#   'Often',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Very difficult',
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 45),
#   33,
#   'Male',
#   'United States',
#   'UT',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '100-500',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 45),
#   31,
#   'M',
#   'United States',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '100-500',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'Maybe',
#   'Some of them',
#   'Some of them',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 45),
#   32,
#   'Male',
#   'United States',
#   'TN',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 46),
#   28,
#   'M',
#   'Switzerland',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '100-500',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 46),
#   27,
#   'Male-ish',
#   'United States',
#   'NY',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   "Don't know",
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 46),
#   32,
#   'maile',
#   'United States',
#   'TN',
#   'No',
#   'Yes',
#   'No',
#   'NA',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 47),
#   24,
#   'Male',
#   'United States',
#   'NY',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'Maybe',
#   'Some of them',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 47),
#   26,
#   'Male',
#   'United States',
#   'TN',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '26-100',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 47),
#   33,
#   'male',
#   'Canada',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Often',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   'No',
#   'Somewhat difficult',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 48),
#   44,
#   'Male',
#   'United States',
#   'IA',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   'More than 1000',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 11, 49),
#   26,
#   'Female',
#   'Poland',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 50),
#   27,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '100-500',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'No',
#   'Yes',
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 50),
#   26,
#   'Male',
#   'France',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '26-100',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Very easy',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 11, 50),
#   35,
#   'male',
#   'Canada',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 51),
#   40,
#   'Male',
#   'United States',
#   'CA',
#   'No',
#   'Yes',
#   'No',
#   'Sometimes',
#   'More than 1000',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 11, 51),
#   23,
#   'Female',
#   'Australia',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Often',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 52),
#   36,
#   'M',
#   'United States',
#   'TX',
#   'No',
#   'No',
#   'No',
#   'Sometimes',
#   '100-500',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   "Don't know",
#   'Yes',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'Maybe',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 52),
#   31,
#   'Female',
#   'United States',
#   'NM',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '26-100',
#   'Yes',
#   'No',
#   "Don't know",
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 52),
#   34,
#   'Male',
#   'United States',
#   'NY',
#   'Yes',
#   'No',
#   'No',
#   'Rarely',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 53),
#   28,
#   'm',
#   'France',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '26-100',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 53),
#   34,
#   'male',
#   'Canada',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 54),
#   23,
#   'Trans-female',
#   'United States',
#   'MA',
#   'No',
#   'No',
#   'No',
#   'Rarely',
#   'More than 1000',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat difficult',
#   'Maybe',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 56),
#   38,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '26-100',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 56),
#   33,
#   'Male',
#   'United States',
#   'CA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   'More than 1000',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'Yes',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 57),
#   19,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '5-Jan',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Somewhat difficult',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 57),
#   25,
#   'Male',
#   'United States',
#   'WA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   'More than 1000',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 57),
#   31,
#   'Male',
#   'United States',
#   'WA',
#   'Yes',
#   'Yes',
#   'No',
#   'Sometimes',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat difficult',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 11, 59),
#   32,
#   'Male',
#   'United States',
#   'UT',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat difficult',
#   'Yes',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 0),
#   28,
#   'm',
#   'Germany',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'Maybe',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 1),
#   38,
#   'Male',
#   'United States',
#   'NY',
#   'No',
#   'Yes',
#   'No',
#   'Sometimes',
#   '100-500',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Some of them',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 2),
#   23,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'Yes',
#   "Don't know",
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 2),
#   30,
#   'male',
#   'Canada',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '26-100',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 3),
#   27,
#   'Cis Female',
#   'United States',
#   'NY',
#   'Yes',
#   'No',
#   'Yes',
#   'Often',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Very easy',
#   'Maybe',
#   'Maybe',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 5),
#   33,
#   'Male',
#   'United States',
#   'CA',
#   'No',
#   'Yes',
#   'No',
#   'Never',
#   'More than 1000',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 5),
#   31,
#   'Male',
#   'United States',
#   'TX',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 7),
#   39,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'Yes',
#   'No',
#   'Yes',
#   'Often',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Very difficult',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 12, 10),
#   34,
#   'female',
#   'United States',
#   'OR',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '500-1000',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'Some of them',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 11),
#   29,
#   'F',
#   'United States',
#   'FL',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 12, 11),
#   32,
#   'M',
#   'United States',
#   'IL',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '500-1000',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 12),
#   31,
#   'Male',
#   'United States',
#   'NY',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '500-1000',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 13),
#   40,
#   'male',
#   'United States',
#   'TX',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Very difficult',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 14),
#   34,
#   'Male',
#   'United States',
#   'OH',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 15),
#   25,
#   'F',
#   'Canada',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 15),
#   29,
#   'male',
#   'United States',
#   'MN',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 16),
#   24,
#   'Male',
#   'United States',
#   'MO',
#   'No',
#   'Yes',
#   'No',
#   'Rarely',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Somewhat easy',
#   'Maybe',
#   'Maybe',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 17),
#   31,
#   'male',
#   'Mexico',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Yes',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 18),
#   33,
#   'Cis Male',
#   'United States',
#   'AZ',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 18),
#   30,
#   'M',
#   'United States',
#   'IN',
#   'No',
#   'No',
#   'Yes',
#   'Often',
#   '5-Jan',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 18),
#   26,
#   'female',
#   'Canada',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Very difficult',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 12, 18),
#   44,
#   'Female',
#   'United States',
#   'MA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '100-500',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 19),
#   25,
#   'Male',
#   'United States',
#   'NY',
#   'No',
#   'Yes',
#   'No',
#   'NA',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 20),
#   33,
#   'Male',
#   'United States',
#   'WI',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 22),
#   29,
#   'Male',
#   'United States',
#   'NY',
#   'No',
#   'No',
#   'No',
#   'Never',
#   'More than 1000',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'Yes',
#   "Don't know",
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 23),
#   35,
#   'Male',
#   'United States',
#   'MO',
#   'No',
#   'Yes',
#   'No',
#   'Rarely',
#   '25-Jun',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 23),
#   35,
#   'M',
#   'United States',
#   'OR',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 25),
#   28,
#   'Male',
#   'Brazil',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Maybe',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 12, 28),
#   34,
#   'm',
#   'United States',
#   'TN',
#   'No',
#   'Yes',
#   'No',
#   'Never',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 28),
#   32,
#   'Male',
#   'United States',
#   'WA',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Somewhat difficult',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 29),
#   22,
#   'Male',
#   'United States',
#   'NY',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '500-1000',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   "Don't know",
#   'Yes',
#   "Don't know",
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 31),
#   28,
#   'Male',
#   'United States',
#   'CA',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 31),
#   45,
#   'male',
#   'United States',
#   'MO',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 31),
#   32,
#   'Male',
#   'United States',
#   'NY',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '100-500',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 31),
#   28,
#   'male',
#   'United States',
#   'TX',
#   'No',
#   'No',
#   'No',
#   'NA',
#   'More than 1000',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 31),
#   26,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'No',
#   "Don't know",
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 12, 31),
#   21,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'Yes',
#   'No',
#   'No',
#   'Often',
#   '5-Jan',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Very difficult',
#   'Yes',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 31),
#   27,
#   'Male',
#   'Canada',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Rarely',
#   '25-Jun',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Very easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 31),
#   18,
#   'Male',
#   'United States',
#   'CT',
#   'No',
#   'No',
#   'Yes',
#   'Rarely',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 32),
#   35,
#   'Male',
#   'United States',
#   'CO',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '26-100',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 32),
#   29,
#   'Male',
#   'United States',
#   'GA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   'More than 1000',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 33),
#   25,
#   'Male',
#   'United States',
#   'DC',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '26-100',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 33),
#   33,
#   'Male',
#   'United States',
#   'MN',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 33),
#   36,
#   'Male',
#   'United States',
#   'WA',
#   'No',
#   'No',
#   'No',
#   'Often',
#   '25-Jun',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   "Don't know",
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 33),
#   27,
#   'Male',
#   'Canada',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Never',
#   '100-500',
#   'No',
#   'No',
#   'Yes',
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   'Very difficult',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 12, 34),
#   27,
#   'Male',
#   'United States',
#   'WA',
#   'No',
#   'Yes',
#   'No',
#   'Never',
#   '500-1000',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Yes',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 34),
#   27,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 34),
#   32,
#   'M',
#   'United States',
#   'OR',
#   'No',
#   'No',
#   'Yes',
#   'Rarely',
#   '100-500',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 34),
#   31,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'Yes',
#   'No',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'Maybe',
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 34),
#   19,
#   'male',
#   'Slovenia',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'Yes',
#   'Yes',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 34),
#   33,
#   'Male',
#   'United States',
#   'IL',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   'More than 1000',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'Very easy',
#   'Maybe',
#   'No',
#   'Yes',
#   'Some of them',
#   'No',
#   'Yes',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 35),
#   32,
#   'male',
#   'United States',
#   'CA',
#   'No',
#   'No',
#   'No',
#   'Rarely',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'Very difficult',
#   'Maybe',
#   'No',
#   'Yes',
#   'Some of them',
#   'No',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 36),
#   27,
#   'Male',
#   'United States',
#   'NE',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 36),
#   38,
#   'Male',
#   'Costa Rica',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '26-100',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Yes',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 36),
#   24,
#   'Male',
#   'Canada',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Never',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 37),
#   39,
#   'M',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '26-100',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 37),
#   28,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 37),
#   39,
#   'Male',
#   'United States',
#   'IA',
#   'No',
#   'No',
#   'Yes',
#   'Often',
#   'More than 1000',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 37),
#   29,
#   'Female',
#   'United States',
#   'MD',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Somewhat easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 37),
#   22,
#   'm',
#   'Austria',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   "Don't know",
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 38),
#   38,
#   'Male',
#   'United States',
#   'OR',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '100-500',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 38),
#   37,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'Yes',
#   'No',
#   'Yes',
#   'Sometimes',
#   'More than 1000',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Very difficult',
#   'Yes',
#   'Yes',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 38),
#   35,
#   'M',
#   'United States',
#   'TX',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '26-100',
#   'Yes',
#   'No',
#   "Don't know",
#   'Not sure',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 39),
#   -29,
#   'Male',
#   'United States',
#   'MN',
#   'No',
#   'No',
#   'No',
#   'NA',
#   'More than 1000',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   "Don't know",
#   'Yes',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 39),
#   30,
#   'Female',
#   'United States',
#   'PA',
#   'No',
#   'Yes',
#   'No',
#   'NA',
#   'More than 1000',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'Maybe',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 39),
#   37,
#   'Male',
#   'United States',
#   'IN',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '100-500',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Somewhat easy',
#   'Maybe',
#   'Maybe',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 39),
#   24,
#   'M',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   "Don't know",
#   'Maybe',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 39),
#   23,
#   'Male',
#   'United States',
#   'WV',
#   'No',
#   'No',
#   'No',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Somewhat easy',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 40),
#   30,
#   'male',
#   'Ireland',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Rarely',
#   '100-500',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Somewhat easy',
#   'Yes',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 12, 40),
#   29,
#   'Female',
#   'United States',
#   'MI',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '100-500',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'No',
#   'Some of them',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 40),
#   19,
#   'Male',
#   'Canada',
#   'NA',
#   'Yes',
#   'Yes',
#   'No',
#   'NA',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   'Yes',
#   'Yes',
#   'Somewhat easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 40),
#   32,
#   'male',
#   'United States',
#   'CA',
#   'No',
#   'Yes',
#   'No',
#   'Never',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 41),
#   28,
#   'male',
#   'Poland',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Rarely',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 41),
#   36,
#   'Male',
#   'United States',
#   'IL',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 41),
#   37,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   'More than 1000',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Somewhat difficult',
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 27, 12, 42),
#   25,
#   'Male',
#   'United States',
#   'IL',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'No',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Somewhat difficult',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 42),
#   27,
#   'Male',
#   'United States',
#   'CA',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   'More than 1000',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   'Some of them',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 43),
#   26,
#   'male',
#   'United States',
#   'OK',
#   'No',
#   'No',
#   'No',
#   'Often',
#   '26-100',
#   'No',
#   'No',
#   "Don't know",
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 27, 12, 43),
#   27,
#   'male',
#   'United States',
#   'UT',
# ...
#   40,
#   'Male',
#   'United States',
#   'WA',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Very easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 0, 47),
#   34,
#   'Male',
#   'Netherlands',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Rarely',
#   '26-100',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 1, 14),
#   24,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Often',
#   '26-100',
#   'No',
#   'No',
#   "Don't know",
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Somewhat easy',
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 1, 20),
#   61,
#   'male',
#   'South Africa',
#   'NA',
#   'Yes',
#   'No',
#   'Yes',
#   'Sometimes',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Very difficult',
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 1, 40),
#   36,
#   'Female ',
#   'United States',
#   'WA',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 2, 10),
#   38,
#   'Male',
#   'United States',
#   'TN',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 2, 24),
#   33,
#   'male',
#   'Germany',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Often',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'Yes',
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 3, 2),
#   30,
#   'male',
#   'United States',
#   'WA',
#   'No',
#   'Yes',
#   'No',
#   'Never',
#   'More than 1000',
#   'No',
#   'No',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 3, 2),
#   34,
#   'male',
#   'Netherlands',
#   'NA',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Some of them',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 3, 8),
#   26,
#   'Male',
#   'United States',
#   'CA',
#   'No',
#   'No',
#   'Yes',
#   'Rarely',
#   'More than 1000',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 4, 39),
#   33,
#   'M',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   'More than 1000',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 4, 53),
#   32,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 5, 15),
#   25,
#   'male',
#   'Germany',
#   'NA',
#   'Yes',
#   'No',
#   'No',
#   'Sometimes',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 5, 24),
#   35,
#   'male',
#   'Germany',
#   'NA',
#   'Yes',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'Yes',
#   'No',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat difficult',
#   'Yes',
#   'Maybe',
#   'Yes',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 5, 39),
#   24,
#   'M',
#   'United Kingdom',
#   'NA',
#   'Yes',
#   'Yes',
#   'No',
#   'Often',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 5, 47),
#   55,
#   'male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Often',
#   'More than 1000',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Somewhat easy',
#   'Yes',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 5, 54),
#   33,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Very difficult',
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 5, 57),
#   26,
#   'Female',
#   'United Kingdom',
#   'NA',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Very easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 6, 6),
#   25,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 6, 37),
#   45,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'Yes',
#   'No',
#   'Rarely',
#   '100-500',
#   'No',
#   'No',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 6, 42),
#   33,
#   'female',
#   'United Kingdom',
#   'NA',
#   'Yes',
#   'No',
#   'Yes',
#   'Sometimes',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 7, 12),
#   43,
#   'Male',
#   'United States',
#   'MI',
#   'No',
#   'No',
#   'No',
#   'Sometimes',
#   'More than 1000',
#   'Yes',
#   'Yes',
#   'No',
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   'Very difficult',
#   'Yes',
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 7, 21),
#   30,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'Yes',
#   'No',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'Very difficult',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 7, 28),
#   40,
#   'Male',
#   'United States',
#   'IN',
#   'No',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 7, 51),
#   49,
#   'Male',
#   'United States',
#   'GA',
#   'No',
#   'Yes',
#   'No',
#   'Never',
#   'More than 1000',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 8, 26),
#   29,
#   'Male',
#   'Germany',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '25-Jun',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'Maybe',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 8, 36),
#   26,
#   'male',
#   'Germany',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '500-1000',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'Some of them',
#   'Some of them',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 8, 46),
#   38,
#   'cis male',
#   'United States',
#   'WA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   'More than 1000',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Somewhat easy',
#   'Maybe',
#   'Maybe',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Maybe',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 8, 53),
#   27,
#   'Male',
#   'France',
#   'NA',
#   'No',
#   'Yes',
#   'No',
#   'NA',
#   '500-1000',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'Maybe',
#   'Maybe',
#   'No',
#   'Some of them',
#   'No',
#   'Maybe',
#   "Don't know",
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 8, 54),
#   26,
#   'male',
#   'Belgium',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '25-Jun',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Somewhat easy',
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 8, 57),
#   28,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Often',
#   '26-100',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat easy',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 8, 57),
#   40,
#   'Male',
#   'United States',
#   'ME',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'Maybe',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   'No',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 8, 59),
#   37,
#   'Female',
#   'Canada',
#   'NA',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Rarely',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'Yes',
#   'Maybe',
#   'Some of them',
#   'Some of them',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 8, 59),
#   34,
#   'female',
#   'United Kingdom',
#   'NA',
#   'No',
#   'Yes',
#   'Yes',
#   'Often',
#   '26-100',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'Somewhat easy',
#   'Yes',
#   'Yes',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 1),
#   28,
#   'male',
#   'United States',
#   'NY',
#   'No',
#   'Yes',
#   'Yes',
#   'Often',
#   '100-500',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Some of them',
#   'No',
#   'Yes',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 1),
#   27,
#   'Male',
#   'Canada',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Never',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'Yes',
#   'No',
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 2),
#   29,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 2),
#   39,
#   'Female',
#   'United Kingdom',
#   'NA',
#   'No',
#   'Yes',
#   'No',
#   'Rarely',
#   '500-1000',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   'No',
#   "Don't know",
#   'Somewhat difficult',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 9, 3),
#   28,
#   'male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Often',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Somewhat difficult',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 10),
#   23,
#   'Male',
#   'United States',
#   'PA',
#   'No',
#   'Yes',
#   'No',
#   'Sometimes',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Not sure',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 10),
#   8,
#   'A little about you',
#   'Bahamas, The',
#   'IL',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Often',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Very easy',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes'),
#  (datetime.datetime(2014, 8, 29, 9, 12),
#   38,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 13),
#   19,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '25-Jun',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   "Don't know",
#   'Very easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 14),
#   30,
#   'Female',
#   'United States',
#   'IL',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'Yes',
#   'Very easy',
#   'No',
#   'No',
#   'Some of them',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 15),
#   28,
#   'male',
#   'United Kingdom',
#   'NA',
#   'Yes',
#   'No',
#   'No',
#   'NA',
#   '5-Jan',
#   'Yes',
#   'Yes',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Very easy',
#   'Maybe',
#   'Maybe',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 15),
#   20,
#   'Male',
#   'India',
#   'NA',
#   'No',
#   'No',
#   'Yes',
#   'Sometimes',
#   '26-100',
#   'No',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'Maybe',
#   'Yes',
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 19),
#   35,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'Yes',
#   'No',
#   'No',
#   'Sometimes',
#   '5-Jan',
#   'No',
#   'Yes',
#   "Don't know",
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Somewhat easy',
#   'No',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 24),
#   39,
#   'male',
#   'United States',
#   'MN',
#   'No',
#   'No',
#   'Yes',
#   'Rarely',
#   '100-500',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'Yes',
#   'Very easy',
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 23),
#   31,
#   'Female',
#   'United States',
#   'TX',
#   'No',
#   'Yes',
#   'No',
#   'Never',
#   'More than 1000',
#   'No',
#   'No',
#   'Yes',
#   'Not sure',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 23),
#   32,
#   'Male',
#   'United Kingdom',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'Rarely',
#   '500-1000',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 27),
#   27,
#   'Male',
#   'Sweden',
#   'NA',
#   'No',
#   'No',
#   'No',
#   'NA',
#   '25-Jun',
#   'No',
#   'Yes',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   'No',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 29),
#   25,
#   'Male',
#   'United States',
#   'PA',
#   'No',
#   'Yes',
#   'Yes',
#   'Often',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   'Yes',
#   'Yes',
#   'No',
#   "Don't know",
#   'Yes',
#   'Somewhat easy',
#   'No',
#   'No',
#   'Yes',
#   'Yes',
#   'Maybe',
#   'Maybe',
#   "Don't know",
#   'No'),
#  (datetime.datetime(2014, 8, 29, 9, 31),
#   42,
#   'male',
#   'United States',
#   'IN',
#   'No',
#   'Yes',
#   'Yes',
#   'Sometimes',
#   '25-Jun',
#   'Yes',
#   'Yes',
#   "Don't know",
#   'No',
#   'No',
#   "Don't know",
#   "Don't know",
#   "Don't know",
#   'Maybe',
#   'No',
#   'Some of them',
#   'Yes',
#   'No',
#   'Maybe',
#   "Don't know",
#   'No'),
#  ...]

# %% [markdown]
# ### Questions for Exploration
#
# 1. What is the most common attributes towards mental health in the workplace?
# 2. Does Geographic location matter in terms of mental health awareness?
# 3. Gauge inside the mind of the employee, with the last columns

# %%
mhealth_df= pd.DataFrame(rows, columns = ["timestamp","age","gender","country","state","self_employed","family_history",
                                          "treatment","work_interfere","no_employees","remote_work","tech_company",
                                          "benefits","care_options","wellness_program","seek_help","anonymity",
                                         "leave","mental_health_consequence","phys_health_consequence","coworkers",
                                         "supervisor","mental_health_interview","phys_health_interview","mental_vs_physical",
                                         "obs_consequence"])

mhealth_df.head(20)
# Out:
#              timestamp  age  gender         country state self_employed  \
# 0  2014-08-27 11:29:00   37  Female   United States    IL            NA
# 1  2014-08-27 11:29:00   44       M   United States    IN            NA
# 2  2014-08-27 11:29:00   32    Male          Canada    NA            NA
# 3  2014-08-27 11:29:00   31    Male  United Kingdom    NA            NA
# 4  2014-08-27 11:30:00   31    Male   United States    TX            NA
# 5  2014-08-27 11:31:00   33    Male   United States    TN            NA
# 6  2014-08-27 11:31:00   35  Female   United States    MI            NA
# 7  2014-08-27 11:32:00   39       M          Canada    NA            NA
# 8  2014-08-27 11:32:00   42  Female   United States    IL            NA
# 9  2014-08-27 11:32:00   23    Male          Canada    NA            NA
# 10 2014-08-27 11:32:00   31    Male   United States    OH            NA
# 11 2014-08-27 11:32:00   29    male        Bulgaria    NA            NA
# 12 2014-08-27 11:33:00   42  female   United States    CA            NA
# 13 2014-08-27 11:33:00   36    Male   United States    CT            NA
# 14 2014-08-27 11:33:00   27    Male          Canada    NA            NA
# 15 2014-08-27 11:34:00   29  female   United States    IL            NA
# 16 2014-08-27 11:34:00   23    Male  United Kingdom    NA            NA
# 17 2014-08-27 11:34:00   32    Male   United States    TN            NA
# 18 2014-08-27 11:34:00   46    male   United States    MD           Yes
# 19 2014-08-27 11:35:00   36    Male          France    NA           Yes
#
#    family_history treatment work_interfere    no_employees  ...   anonymity  \
# 0              No       Yes          Often          25-Jun  ...         Yes
# 1              No        No         Rarely  More than 1000  ...  Don't know
# 2              No        No         Rarely          25-Jun  ...  Don't know
# 3             Yes       Yes          Often          26-100  ...          No
# 4              No        No          Never         100-500  ...  Don't know
# 5             Yes        No      Sometimes          25-Jun  ...  Don't know
# 6             Yes       Yes      Sometimes           5-Jan  ...          No
# 7              No        No          Never           5-Jan  ...         Yes
# 8             Yes       Yes      Sometimes         100-500  ...          No
# 9              No        No          Never          26-100  ...  Don't know
# 10             No       Yes      Sometimes          25-Jun  ...  Don't know
# 11             No        No          Never         100-500  ...  Don't know
# 12            Yes       Yes      Sometimes          26-100  ...  Don't know
# 13            Yes        No          Never        500-1000  ...  Don't know
# 14             No        No          Never          25-Jun  ...  Don't know
# 15            Yes       Yes         Rarely          26-100  ...  Don't know
# 16             No       Yes      Sometimes          26-100  ...  Don't know
# 17             No       Yes      Sometimes          25-Jun  ...  Don't know
# 18            Yes        No      Sometimes           5-Jan  ...         Yes
# 19            Yes        No             NA          25-Jun  ...         Yes
#
#                  leave mental_health_consequence phys_health_consequence  \
# 0        Somewhat easy                        No                      No
# 1           Don't know                     Maybe                      No
# 2   Somewhat difficult                        No                      No
# 3   Somewhat difficult                       Yes                     Yes
# 4           Don't know                        No                      No
# 5           Don't know                        No                      No
# 6   Somewhat difficult                     Maybe                   Maybe
# 7           Don't know                        No                      No
# 8       Very difficult                     Maybe                      No
# 9           Don't know                        No                      No
# 10          Don't know                        No                      No
# 11          Don't know                        No                      No
# 12  Somewhat difficult                       Yes                     Yes
# 13          Don't know                        No                      No
# 14       Somewhat easy                        No                      No
# 15       Somewhat easy                        No                      No
# 16           Very easy                     Maybe                      No
# 17          Don't know                     Maybe                      No
# 18           Very easy                        No                      No
# 19       Somewhat easy                        No                      No
#
#        coworkers    supervisor mental_health_interview phys_health_interview  \
# 0   Some of them           Yes                      No                 Maybe
# 1             No            No                      No                    No
# 2            Yes           Yes                     Yes                   Yes
# 3   Some of them            No                   Maybe                 Maybe
# 4   Some of them           Yes                     Yes                   Yes
# 5            Yes           Yes                      No                 Maybe
# 6   Some of them            No                      No                    No
# 7             No            No                      No                    No
# 8            Yes           Yes                      No                 Maybe
# 9            Yes           Yes                   Maybe                 Maybe
# 10  Some of them           Yes                      No                    No
# 11           Yes           Yes                     Yes                   Yes
# 12           Yes           Yes                   Maybe                 Maybe
# 13           Yes           Yes                      No                    No
# 14  Some of them  Some of them                   Maybe                   Yes
# 15           Yes  Some of them                   Maybe                 Maybe
# 16  Some of them            No                   Maybe                 Maybe
# 17  Some of them           Yes                      No                    No
# 18           Yes           Yes                      No                   Yes
# 19  Some of them  Some of them                   Maybe                 Maybe
#
#    mental_vs_physical obs_consequence
# 0                 Yes              No
# 1          Don't know              No
# 2                  No              No
# 3                  No             Yes
# 4          Don't know              No
# 5          Don't know              No
# 6          Don't know              No
# 7                  No              No
# 8                  No              No
# 9                 Yes              No
# 10         Don't know              No
# 11         Don't know              No
# 12                 No             Yes
# 13         Don't know              No
# 14                Yes              No
# 15         Don't know              No
# 16                 No              No
# 17                 No              No
# 18                Yes             Yes
# 19         Don't know              No
#
# [20 rows x 26 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ##### Primary Dataframe Glance
# Consists of 26 columns, no primary keys. Need to check data types

# %%
# Check Data Types
mhealth_df.dtypes
# Out:
# timestamp                    datetime64[ns]
# age                                   int64
# gender                               object
# country                              object
# state                                object
# self_employed                        object
# family_history                       object
# treatment                            object
# work_interfere                       object
# no_employees                         object
# remote_work                          object
# tech_company                         object
# benefits                             object
# care_options                         object
# wellness_program                     object
# seek_help                            object
# anonymity                            object
# leave                                object
# mental_health_consequence            object
# phys_health_consequence              object
# coworkers                            object
# supervisor                           object
# mental_health_interview              object
# phys_health_interview                object
# mental_vs_physical                   object
# obs_consequence                      object
# dtype: object

# %%
# Calculate Sum of NA Values

# Our Self-Eployed/work-interfere Columns have NA vlaues but is not being pulled in as a null value 
mhealth_df.isnull().sum().sort_values(ascending=False)
# Out:
# obs_consequence              0
# mental_vs_physical           0
# age                          0
# gender                       0
# country                      0
# state                        0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# timestamp                    0
# dtype: int64

# %% [markdown]
# ## Drop Irrelevant Columns
#
# Let's review columns and determine if they need to be dropped
# - Going to drop column, due to irrelevance in end product of this project
# - Removing column, due to irrelevance in end product. Only relevant to people in USA

# %%
mhealth_df.drop('timestamp', axis=1, inplace=True)
mhealth_df.drop('state', axis=1, inplace=True)

# %%
mhealth_df.head(10)
# Out:
#    age  gender         country self_employed family_history treatment  \
# 0   37  Female   United States            NA             No       Yes
# 1   44       M   United States            NA             No        No
# 2   32    Male          Canada            NA             No        No
# 3   31    Male  United Kingdom            NA            Yes       Yes
# 4   31    Male   United States            NA             No        No
# 5   33    Male   United States            NA            Yes        No
# 6   35  Female   United States            NA            Yes       Yes
# 7   39       M          Canada            NA             No        No
# 8   42  Female   United States            NA            Yes       Yes
# 9   23    Male          Canada            NA             No        No
#
#   work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 0          Often          25-Jun          No          Yes  ...         Yes
# 1         Rarely  More than 1000          No           No  ...  Don't know
# 2         Rarely          25-Jun          No          Yes  ...  Don't know
# 3          Often          26-100          No          Yes  ...          No
# 4          Never         100-500         Yes          Yes  ...  Don't know
# 5      Sometimes          25-Jun          No          Yes  ...  Don't know
# 6      Sometimes           5-Jan         Yes          Yes  ...          No
# 7          Never           5-Jan         Yes          Yes  ...         Yes
# 8      Sometimes         100-500          No          Yes  ...          No
# 9          Never          26-100          No          Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
# 5          Don't know                        No                      No
# 6  Somewhat difficult                     Maybe                   Maybe
# 7          Don't know                        No                      No
# 8      Very difficult                     Maybe                      No
# 9          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
# 5           Yes        Yes                      No                 Maybe
# 6  Some of them         No                      No                    No
# 7            No         No                      No                    No
# 8           Yes        Yes                      No                 Maybe
# 9           Yes        Yes                   Maybe                 Maybe
#
#   mental_vs_physical obs_consequence
# 0                Yes              No
# 1         Don't know              No
# 2                 No              No
# 3                 No             Yes
# 4         Don't know              No
# 5         Don't know              No
# 6         Don't know              No
# 7                 No              No
# 8                 No              No
# 9                Yes              No
#
# [10 rows x 24 columns]

# %% [markdown]
# ### DataFrame Column Check
#
# We notice how there are indexes, but with this data we notice how there is not a primary key involved.
# Lets Transpose this dataframe for better visuals

# %%
mhealth_df.T
# Out:
#                                     0               1                   2     \
# age                                   37              44                  32
# gender                            Female               M                Male
# country                    United States   United States              Canada
# self_employed                         NA              NA                  NA
# family_history                        No              No                  No
# treatment                            Yes              No                  No
# work_interfere                     Often          Rarely              Rarely
# no_employees                      25-Jun  More than 1000              25-Jun
# remote_work                           No              No                  No
# tech_company                         Yes              No                 Yes
# benefits                             Yes      Don't know                  No
# care_options                    Not sure              No                  No
# wellness_program                      No      Don't know                  No
# seek_help                            Yes      Don't know                  No
# anonymity                            Yes      Don't know          Don't know
# leave                      Somewhat easy      Don't know  Somewhat difficult
# mental_health_consequence             No           Maybe                  No
# phys_health_consequence               No              No                  No
# coworkers                   Some of them              No                 Yes
# supervisor                           Yes              No                 Yes
# mental_health_interview               No              No                 Yes
# phys_health_interview              Maybe              No                 Yes
# mental_vs_physical                   Yes      Don't know                  No
# obs_consequence                       No              No                  No
#
#                                          3              4              5     \
# age                                        31             31             33
# gender                                   Male           Male           Male
# country                        United Kingdom  United States  United States
# self_employed                              NA             NA             NA
# family_history                            Yes             No            Yes
# treatment                                 Yes             No             No
# work_interfere                          Often          Never      Sometimes
# no_employees                           26-100        100-500         25-Jun
# remote_work                                No            Yes             No
# tech_company                              Yes            Yes            Yes
# benefits                                   No            Yes            Yes
# care_options                              Yes             No       Not sure
# wellness_program                           No     Don't know             No
# seek_help                                  No     Don't know     Don't know
# anonymity                                  No     Don't know     Don't know
# leave                      Somewhat difficult     Don't know     Don't know
# mental_health_consequence                 Yes             No             No
# phys_health_consequence                   Yes             No             No
# coworkers                        Some of them   Some of them            Yes
# supervisor                                 No            Yes            Yes
# mental_health_interview                 Maybe            Yes             No
# phys_health_interview                   Maybe            Yes          Maybe
# mental_vs_physical                         No     Don't know     Don't know
# obs_consequence                           Yes             No             No
#
#                                          6           7               8     \
# age                                        35          39              42
# gender                                 Female           M          Female
# country                         United States      Canada   United States
# self_employed                              NA          NA              NA
# family_history                            Yes          No             Yes
# treatment                                 Yes          No             Yes
# work_interfere                      Sometimes       Never       Sometimes
# no_employees                            5-Jan       5-Jan         100-500
# remote_work                               Yes         Yes              No
# tech_company                              Yes         Yes             Yes
# benefits                                   No          No             Yes
# care_options                               No         Yes             Yes
# wellness_program                           No          No              No
# seek_help                                  No          No              No
# anonymity                                  No         Yes              No
# leave                      Somewhat difficult  Don't know  Very difficult
# mental_health_consequence               Maybe          No           Maybe
# phys_health_consequence                 Maybe          No              No
# coworkers                        Some of them          No             Yes
# supervisor                                 No          No             Yes
# mental_health_interview                    No          No              No
# phys_health_interview                      No          No           Maybe
# mental_vs_physical                 Don't know          No              No
# obs_consequence                            No          No              No
#
#                                  9     ...           1247           1248  \
# age                                23  ...             30             30
# gender                           Male  ...              M           Male
# country                        Canada  ...  United States  United States
# self_employed                      NA  ...             No            Yes
# family_history                     No  ...            Yes            Yes
# treatment                          No  ...            Yes            Yes
# work_interfere                  Never  ...      Sometimes          Often
# no_employees                   26-100  ...         26-100         26-100
# remote_work                        No  ...             No             No
# tech_company                      Yes  ...            Yes            Yes
# benefits                   Don't know  ...            Yes            Yes
# care_options                       No  ...            Yes       Not sure
# wellness_program           Don't know  ...     Don't know            Yes
# seek_help                  Don't know  ...             No            Yes
# anonymity                  Don't know  ...            Yes     Don't know
# leave                      Don't know  ...      Very easy     Don't know
# mental_health_consequence          No  ...             No             No
# phys_health_consequence            No  ...             No             No
# coworkers                         Yes  ...            Yes   Some of them
# supervisor                        Yes  ...            Yes            Yes
# mental_health_interview         Maybe  ...          Maybe          Maybe
# phys_health_interview           Maybe  ...          Maybe          Maybe
# mental_vs_physical                Yes  ...            Yes            Yes
# obs_consequence                    No  ...             No             No
#
#                                     1249           1250            1251  \
# age                                   36             29              36
# gender                              Male           male            Male
# country                     South Africa  United States   United States
# self_employed                         No             No              No
# family_history                       Yes            Yes             Yes
# treatment                            Yes            Yes              No
# work_interfere                     Often      Sometimes          Rarely
# no_employees                     100-500        100-500  More than 1000
# remote_work                           No            Yes              No
# tech_company                          No            Yes              No
# benefits                              No            Yes      Don't know
# care_options                         Yes            Yes              No
# wellness_program                      No            Yes             Yes
# seek_help                             No             No             Yes
# anonymity                     Don't know            Yes      Don't know
# leave                      Somewhat easy     Don't know   Somewhat easy
# mental_health_consequence             No            Yes           Maybe
# phys_health_consequence               No             No           Maybe
# coworkers                   Some of them   Some of them    Some of them
# supervisor                           Yes             No    Some of them
# mental_health_interview               No             No              No
# phys_health_interview                Yes          Maybe              No
# mental_vs_physical                   Yes             No      Don't know
# obs_consequence                       No             No              No
#
#                                      1252                1253  \
# age                                    26                  32
# gender                               male                Male
# country                    United Kingdom       United States
# self_employed                          No                  No
# family_history                         No                 Yes
# treatment                             Yes                 Yes
# work_interfere                         NA               Often
# no_employees                       26-100              26-100
# remote_work                            No                 Yes
# tech_company                          Yes                 Yes
# benefits                               No                 Yes
# care_options                           No                 Yes
# wellness_program                       No                  No
# seek_help                              No                  No
# anonymity                      Don't know                 Yes
# leave                       Somewhat easy  Somewhat difficult
# mental_health_consequence              No                  No
# phys_health_consequence                No                  No
# coworkers                    Some of them        Some of them
# supervisor                   Some of them                 Yes
# mental_health_interview                No                  No
# phys_health_interview                  No                  No
# mental_vs_physical             Don't know                 Yes
# obs_consequence                        No                  No
#
#                                          1254           1255           1256
# age                                        34             46             25
# gender                                   male              f           Male
# country                         United States  United States  United States
# self_employed                              No             No             No
# family_history                            Yes             No            Yes
# treatment                                 Yes             No            Yes
# work_interfere                      Sometimes             NA      Sometimes
# no_employees                   More than 1000        100-500         26-100
# remote_work                                No            Yes             No
# tech_company                              Yes            Yes             No
# benefits                                  Yes             No            Yes
# care_options                              Yes            Yes            Yes
# wellness_program                           No             No             No
# seek_help                                  No             No             No
# anonymity                          Don't know     Don't know            Yes
# leave                      Somewhat difficult     Don't know     Don't know
# mental_health_consequence                 Yes            Yes          Maybe
# phys_health_consequence                   Yes             No             No
# coworkers                                  No             No   Some of them
# supervisor                                 No             No             No
# mental_health_interview                    No             No             No
# phys_health_interview                      No             No             No
# mental_vs_physical                         No             No     Don't know
# obs_consequence                            No             No             No
#
# [24 rows x 1257 columns]

# %% [markdown]
# #### Work_Interfere Column

# %%
print(mhealth_df['work_interfere'].unique())
# Out:
# ['Often' 'Rarely' 'Never' 'Sometimes' 'NA']

# %% [markdown]
# #### People that answer NA, do not have a diagnosed medical condition
#
# According to data description 'work_interfere' asks the question,
#
# -'If you have a mental health condition, do you feel that it interferes with your work?'.

# %%
# This will not change my NA Values, due to datatype from Postgresql,

# In theory, this code will change NA values to NA
mhealth_df['work_interfere'] = mhealth_df['work_interfere'].fillna('No Answer')
print("\n",mhealth_df['work_interfere'].unique(),"\n")
# Out:
#  ['Often' 'Rarely' 'Never' 'Sometimes' 'NA']

# %%
# Replacing all NA Values with No Answer

# Alternative Way to changing NA values
# Could have changed a single column, decided to change whole dataframe, for Visualizations
data=mhealth_df.replace('NA','No Answer')
data.head()
# Out:
#    age  gender         country self_employed family_history treatment  \
# 0   37  Female   United States     No Answer             No       Yes
# 1   44       M   United States     No Answer             No        No
# 2   32    Male          Canada     No Answer             No        No
# 3   31    Male  United Kingdom     No Answer            Yes       Yes
# 4   31    Male   United States     No Answer             No        No
#
#   work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 0          Often          25-Jun          No          Yes  ...         Yes
# 1         Rarely  More than 1000          No           No  ...  Don't know
# 2         Rarely          25-Jun          No          Yes  ...  Don't know
# 3          Often          26-100          No          Yes  ...          No
# 4          Never         100-500         Yes          Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence
# 0                Yes              No
# 1         Don't know              No
# 2                 No              No
# 3                 No             Yes
# 4         Don't know              No
#
# [5 rows x 24 columns]

# %%
n = len(pd.unique(data["work_interfere"]))

print("No. of unique values:", n)

print(data["work_interfere"].unique())
# Out:
# No. of unique values: 5
# ['Often' 'Rarely' 'Never' 'Sometimes' 'No Answer']

# %% [markdown]
# ## Optimized DataFrame Column Check with Customized For Loop
# Instead of Checking each unique values per line of code, lets create a for loop

# %%
unique_column_values= {}

for column in data.columns:
    unique_column_values[column] = data[column].unique()

# %% [markdown]
# ##### Age Column
# Dropping all non-relevant ages

# %%
# Call Age Column

unique_column_values["age"]
# Out:
# array([   37,    44,    32,    31,    33,    35,    39,    42,    23,
#           29,    36,    27,    46,    41,    34,    30,    40,    38,
#           50,    24,    18,    28,    26,    22,    19,    25,    45,
#           21,   -29,    43,    56,    60,    54,   329,    55,    48,
#           20,    57,    58,    47,    62,    51,    65,    49, -1726,
#            5,    53,    61,     8,    11,    -1,    72])

# %%
max_age= unique_column_values['age'].max()
print(f'The max age is {max_age}')
# Out:
# The max age is 329

# %%
min_age= unique_column_values['age'].min()
print(f'The min age is {min_age}')
# Out:
# The min age is -1726

# %%
# Delete rows from a pandas DataFrame based on a conditional expression

data = data.drop(data[(data.age <=0) | (data.age > 120)].index)

data["age"].unique()
# Out:
# array([37, 44, 32, 31, 33, 35, 39, 42, 23, 29, 36, 27, 46, 41, 34, 30, 40,
#        38, 50, 24, 18, 28, 26, 22, 19, 25, 45, 21, 43, 56, 60, 54, 55, 48,
#        20, 57, 58, 47, 62, 51, 65, 49,  5, 53, 61,  8, 11, 72])

# %% [markdown]
# #### Gender Column
# For the purpose of this project, making 3 categiories for Gender

# %%
# Call Gender Column

unique_column_values["gender"]
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'Cis Male', 'Woman', 'f', 'Mal',
#        'Male (CIS)', 'queer/she/they', 'non-binary', 'Femake', 'woman',
#        'Make', 'Nah', 'Enby', 'fluid', 'Genderqueer', 'Female ',
#        'Androgyne', 'Agender', 'male leaning androgynous', 'Male ', 'Man',
#        'Trans woman', 'msle', 'Neuter', 'Female (trans)', 'queer',
#        'Female (cis)', 'Mail', 'cis male', 'A little about you', 'Malr',
#        'p', 'femail', 'Cis Man'], dtype=object)

# %% [markdown]
#  Lots of unique values here,
#
#  Make a list of 3 groups and make all uniform

# %%
male = ['male', 'Male','M', 'm', 'Male-ish', 'maile','Cis Male','Mal', 'Male (CIS)','Make','Male ', 'Man',
        'msle','cis male', 'Cis Man','Malr','Mail']
female = ['Female', 'female','Cis Female', 'F','f','Femake', 'woman','Female ','cis-female/femme','Female (cis)','femail','Woman','female']
other = ['Trans-female','something kinda male?','queer/she/they','non-binary','All','fluid', 'Genderqueer','Androgyne', 'Agender','Guy (-ish) ^_^',
        'male leaning androgynous','Trans woman','Neuter', 'Female (trans)','queer','ostensibly male, unsure what that really means','trans','Nah','Enby','A little about you']

data['gender'].replace(to_replace= male , value = 'male', inplace=True)
data['gender'].replace(to_replace= female , value = 'female', inplace=True)
data['gender'].replace(to_replace= other , value = 'other', inplace=True)

data['gender'].unique()
# Out:
# array(['female', 'male', 'other'], dtype=object)

# %% [markdown]
# #### Country Column
# Make a continent column for easier Visuals

# %%
#### Country Column

unique_column_values['country']
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Bulgaria', 'France',
#        'Portugal', 'Netherlands', 'Switzerland', 'Poland', 'Australia',
#        'Germany', 'Mexico', 'Brazil', 'Slovenia', 'Costa Rica', 'Austria',
#        'Ireland', 'India', 'South Africa', 'Russia', 'Italy', 'Sweden',
#        'Colombia', 'Latvia', 'Romania', 'Belgium', 'New Zealand', 'Spain',
#        'Finland', 'Uruguay', 'Israel', 'Bosnia and Herzegovina',
#        'Hungary', 'Singapore', 'Japan', 'Nigeria', 'Croatia', 'Norway',
#        'Thailand', 'Denmark', 'Bahamas, The', 'Greece', 'Moldova',
#        'Georgia', 'China', 'Czech Republic', 'Philippines'], dtype=object)

# %%
data['country'].replace('Bahamas, The', value = 'The Bahamas', inplace=True)

data['country'].unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Bulgaria', 'France',
#        'Portugal', 'Netherlands', 'Switzerland', 'Poland', 'Australia',
#        'Germany', 'Mexico', 'Brazil', 'Slovenia', 'Costa Rica', 'Austria',
#        'Ireland', 'India', 'South Africa', 'Russia', 'Italy', 'Sweden',
#        'Colombia', 'Latvia', 'Romania', 'Belgium', 'New Zealand', 'Spain',
#        'Finland', 'Uruguay', 'Israel', 'Bosnia and Herzegovina',
#        'Hungary', 'Singapore', 'Japan', 'Nigeria', 'Croatia', 'Norway',
#        'Thailand', 'Denmark', 'The Bahamas', 'Greece', 'Moldova',
#        'Georgia', 'China', 'Czech Republic', 'Philippines'], dtype=object)

# %% [markdown]
# #### Add Another column, based on the conditions of [Country] Column

# %%
continents = {'United States':"North America","Canada":"North America",'United Kingdom':"Europe",'Bulgaria':"Europe",'France':"Europe",
            'Portugal':"Europe",'Netherlands':"Europe",'Switzerland':"Europe",'Poland':"Europe", 'Australia':'Oceania',
              'Germany':"Europe",'Mexico':"North America",'Brazil':"South America",'Slovenia':"Europe",'Costa Rica':"North America",
              'Austria':"Europe",'Ireland':"Europe",'India':"Asia",'South Africa':"Africa",'Russia':"Europe",'Italy':"Europe",
              'Sweden':"Europe",'Colombia':"South America",'Latvia':"Europe",'Romania':"Europe",'Belgium':"Europe",'New Zealand':"Oceania",
              'Spain':"Europe",'Finland':"Europe",'Uruguay':"South America",'Israel':"Europe",'Bosnia and Herzegovina':"Europe",
              'Hungary':"Europe",'Singapore':"Asia",'Japan':"Asia",'Nigeria':"Africa",'Croatia':"Europe",'Norway':"Europe",
              'Thailand':"Asia", 'Denmark':"Europe",'The Bahamas':"North America",'Greece':"Europe",'Moldova':"Europe",'Georgia':"Europe",
              'China':"Asia",'Czech Republic':"Europe",'Philippines':"Asia"
             }

data["continent"] = data["country"].map(continents)
data.head(10)
# Out:
#    age  gender         country self_employed family_history treatment  \
# 0   37  female   United States     No Answer             No       Yes
# 1   44    male   United States     No Answer             No        No
# 2   32    male          Canada     No Answer             No        No
# 3   31    male  United Kingdom     No Answer            Yes       Yes
# 4   31    male   United States     No Answer             No        No
# 5   33    male   United States     No Answer            Yes        No
# 6   35  female   United States     No Answer            Yes       Yes
# 7   39    male          Canada     No Answer             No        No
# 8   42  female   United States     No Answer            Yes       Yes
# 9   23    male          Canada     No Answer             No        No
#
#   work_interfere    no_employees remote_work tech_company  ...  \
# 0          Often          25-Jun          No          Yes  ...
# 1         Rarely  More than 1000          No           No  ...
# 2         Rarely          25-Jun          No          Yes  ...
# 3          Often          26-100          No          Yes  ...
# 4          Never         100-500         Yes          Yes  ...
# 5      Sometimes          25-Jun          No          Yes  ...
# 6      Sometimes           5-Jan         Yes          Yes  ...
# 7          Never           5-Jan         Yes          Yes  ...
# 8      Sometimes         100-500          No          Yes  ...
# 9          Never          26-100          No          Yes  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
# 5          Don't know                        No                      No
# 6  Somewhat difficult                     Maybe                   Maybe
# 7          Don't know                        No                      No
# 8      Very difficult                     Maybe                      No
# 9          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
# 5           Yes        Yes                      No                 Maybe
# 6  Some of them         No                      No                    No
# 7            No         No                      No                    No
# 8           Yes        Yes                      No                 Maybe
# 9           Yes        Yes                   Maybe                 Maybe
#
#   mental_vs_physical obs_consequence      continent
# 0                Yes              No  North America
# 1         Don't know              No  North America
# 2                 No              No  North America
# 3                 No             Yes         Europe
# 4         Don't know              No  North America
# 5         Don't know              No  North America
# 6         Don't know              No  North America
# 7                 No              No  North America
# 8                 No              No  North America
# 9                Yes              No  North America
#
# [10 rows x 25 columns]

# %% [markdown]
# #### Rest of Columns
# Checking unique values

# %%
print(f'Self_Employed columns unique values are, {unique_column_values["self_employed"]}')
print(f'Family_history columns unique values are, {unique_column_values["family_history"]}')
print(f'Treatment columns unique values are, {unique_column_values["treatment"]}')
print(f'No_employees columns unique values are, {unique_column_values["no_employees"]}')
print(f'Remote_work columns unique values are, {unique_column_values["remote_work"]}')
print(f'Tech_company columns unique values are, {unique_column_values["tech_company"]}')
print(f'Benefits columns unique values are, {unique_column_values["benefits"]}')
print(f'Care_Options columns unique values are, {unique_column_values["care_options"]}')
print(f'Wellness_program columns unique values are, {unique_column_values["wellness_program"]}')
print(f'Seek_help columns unique values are, {unique_column_values["seek_help"]}')
print(f'Anonymity columns unique values are, {unique_column_values["anonymity"]}')
print(f'Leave columns unique values are, {unique_column_values["leave"]}')
print(f'Mental_Health_conseq columns unique values are, {unique_column_values["mental_health_consequence"]}')
print(f'Phys_health_conseq columns unique values are, {unique_column_values["phys_health_consequence"]}')
print(f'Coworkers columns unique values are, {unique_column_values["coworkers"]}')
print(f'Supervisor columns unique values are, {unique_column_values["supervisor"]}')
print(f'Mental_health_interview columns unique values are, {unique_column_values["mental_health_interview"]}')
print(f'Phys_health_interview columns unique values are, {unique_column_values["phys_health_interview"]}')
print(f'Mental_vs_Phys columns unique values are, {unique_column_values["mental_vs_physical"]}')
# Out:
# Self_Employed columns unique values are, ['No Answer' 'Yes' 'No']
# Family_history columns unique values are, ['No' 'Yes']
# Treatment columns unique values are, ['Yes' 'No']
# No_employees columns unique values are, ['25-Jun' 'More than 1000' '26-100' '100-500' '5-Jan' '500-1000']
# Remote_work columns unique values are, ['No' 'Yes']
# Tech_company columns unique values are, ['Yes' 'No']
# Benefits columns unique values are, ['Yes' "Don't know" 'No']
# Care_Options columns unique values are, ['Not sure' 'No' 'Yes']
# Wellness_program columns unique values are, ['No' "Don't know" 'Yes']
# Seek_help columns unique values are, ['Yes' "Don't know" 'No']
# Anonymity columns unique values are, ['Yes' "Don't know" 'No']
# Leave columns unique values are, ['Somewhat easy' "Don't know" 'Somewhat difficult' 'Very difficult'
#  'Very easy']
# Mental_Health_conseq columns unique values are, ['No' 'Maybe' 'Yes']
# Phys_health_conseq columns unique values are, ['No' 'Yes' 'Maybe']
# Coworkers columns unique values are, ['Some of them' 'No' 'Yes']
# Supervisor columns unique values are, ['Yes' 'No' 'Some of them']
# Mental_health_interview columns unique values are, ['No' 'Yes' 'Maybe']
# Phys_health_interview columns unique values are, ['Maybe' 'No' 'Yes']
# Mental_vs_Phys columns unique values are, ['Yes' "Don't know" 'No']

# %% [markdown]
# #### No_Employees Column
# No_employees columns unique values are, ['25-Jun' 'More than 1000' '26-100' '100-500' '5-Jan' '500-1000']
#
# Categorize in 5 groups

# %%
less_than_25 = ['5-Jan','25-Jun']
twentysix_to_100= ['26-100']
onehundred_to_500= ['100-500']
fivehundred_to_1K= ['500-1000']
greater_than_1K= ['More than 1000']

data['no_employees'].replace(to_replace= less_than_25 , value = '0-25', inplace=True)
data['no_employees'].replace(to_replace= twentysix_to_100 , value = '26-100', inplace=True)
data['no_employees'].replace(to_replace= onehundred_to_500 , value = '100-500', inplace=True)
data["no_employees"].replace(to_replace= fivehundred_to_1K, value= '500-1000', inplace=True)
data["no_employees"].replace(to_replace= greater_than_1K, value= '1000+', inplace=True)

data["no_employees"].unique()
# Out:
# array(['0-25', '1000+', '26-100', '100-500', '500-1000'], dtype=object)

# %% [markdown]
# ### Export Cleaned CSV File to Folder Structure

# %%
data.to_csv('Resources/mental_health_clean_data.csv', index=False)
